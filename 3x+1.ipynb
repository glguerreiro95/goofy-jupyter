# %%
import matplotlib.pyplot as plt

# %%
x=27
y=0
arrayx = []
arrayy = []
while x != 1:
    if x%2 == 0:
        x = x/2
    else:
        x = (3*x)+1
    y = y+1
    arrayx.append(x)
    arrayy.append(y)
print(x, y)
# Out:
# 1.0 111

# %%
plt.plot(arrayy,arrayx)
plt.show()
